# %%
import pandas as pd

# %%
train_path = '../data/clean/IOB2_train.txt'
val_path   = '../data/clean/IOB2_val.txt'
test_path  = '../data/clean/IOB2_test.txt'

augmentation_path = '../data/augmentation/IOB2_augmentation.txt'

# %%
df[['text']].drop_duplicates().to_csv('../data/text_articles_crime.csv', index=True, index_label='id')

# %% [markdown]
# - PER (Person / Адам): Адамдардың аты-жөні. Мысалдар: Қанат Сұлтанбеков, Игорь Баланды, Бейбіт Шүменов, Дәулет Тұрлыханов.
#
# - ORG (Organization / Ұйым): Мемлекеттік органдар, компаниялар, топтар, агенттіктер. Мысалдар: Ішкі істер министрлігі, Ұлттық қауіпсіздік комитеті, Сыбайлас жемқорлыққа қарсы қызмет, "Астана LRT", Tengrinews.kz, Kaspi.kz.
#
# - LOC (Location / Орналасқан жер): Геосаяси емес нақты орындар (көшелер, ғимараттар, өткізу бекеттері). Мысалдар: "Ақ Тілек Автожол" бақылау-өткізу пункті, MEGA Silk Way сауда орталығы, Байзақов көшесі.
#
# - CRIME_TYPE (Қылмыс түрі): Жасалған қылмыстың нақты атауы. Мысалдар: адам өлтіру, зорлау, алаяқтық, бопсалау, қарақшылық шабуыл, ұрлық, сыбайлас жемқорлық, бұзақылық, контрабанда, адам саудасы.
#
# - LAW (Заң / Кодекс): Заңнамалық актілер мен олардың баптары. Мысалдар: Қылмыстық кодекс, ҚР ҚК-нің 99-бабы, Әкімшілік құқық бұзушылық туралы кодекс.

# %%
df[['text']][:10].to_csv('10_text_articles_crime.csv', index=False)
